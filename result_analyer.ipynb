# %%
import csv
with open('temp2.csv', 'w') as out_file:
    file = input("enter the complete file location!")
    try:
        f = open(file)
    except FileNotFoundError:
        f = None
    if f is not None:
        for line in f:
            writer = csv.writer(out_file)
            if line =='\n'or line == ' ' or 'DATE:' in line or 'C.B.S.E' in line or 'ROLL' in line or 'SCHOOL' in line or 'GR1' in line or '------'in line:
                continue
            else:
                row= line.strip('\n').split()
                if row!=[] :
                    for i in range(1,5):
                        if(row[i]=='M'or row[i]=='F'):
                            row.insert(i,' ')
                    writer.writerow(row)
        f.close()
    else:
        print("Couldn't read the file! Try with appropriate file location")
# Out:
# enter the complete file location!result.txt
# 193
# 199
# 195
# 185
# 198
# 197
# 197
# 177
# 196
# 191
# 187
# 178
# 198
# 191
# 191
# 195
# 191
# 193
# 191
# 191
# 194
# 179
# 195
# 191
# 199
# 200
# 195
# 198
# 198
# 198
# 191
# 191
# 195
# 196
# 200
# 191
# 191
# 191
# 195
# 193
# 192
# 195
# 193
# 196
# 193
# 196
# 194
# 192
# 195
# 196
# 187
# 191
# 197
# 193
# 187
# 197
# 200
# 192
# 196
# 192
# 193
# 191
# 171
# 183
# 195
# 200
# 192
# 194
# 197
# 197
# 191
# 196
# 192
# 191
# 192
# 191
# 196
# 191
# 191
# 195
# 191
# 194
# 196
# 195
# 188
# 193
# 201
# 189
# 198
# 197
# 195
# 195
# 199
# 200
# 197
# 191
# 186
# 195
# 191
# 191
# 192
# 191
# 199
# 200
# 198
# 195
# 196
# 185
# 196
# 191
# 192
# 195
# 195
# 199
# 191
# 182
# 193
# 199
# 197
# 192
# 183
# 180
# 188
# 184
# 180
# 178
# 192
# 176
# 190
# 188
# 183
# 187
# 188
# 187
# 181
# 171
# 171
# 188
# 165
# 171
# 183
# 189
# 185
# 174
# 183
# 179
# 175
# 174
# 172
# 179
# 185
# 176
# 184
# 166
# 173
# 179
# 181
# 161
# 181
# 187
# 182
# 191
# 194
# 181
# 199
# 176
# 194
# 177
# 191
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-ab4d1a1e43fe> in <module>
#      27     if(line!='\n'):
#      28         line = line.split(',')
# ---> 29         print(int(line[6])+int(line[7]))
#
# ValueError: invalid literal for int() with base 10: 'AB'
